# %%
pip show streamlit
# Out:
# Name: streamlit
# Version: 1.32.2
# Summary: A faster way to build and share data apps
# Home-page: https://streamlit.io
# Author: Snowflake Inc
# Author-email: hello@streamlit.io
# License: Apache License 2.0
# Location: E:\PYTHONCODES\talkImage\Lib\site-packages
# Requires: altair, blinker, cachetools, click, gitpython, numpy, packaging, pandas, pillow, protobuf, pyarrow, pydeck, requests, rich, tenacity, toml, tornado, typing-extensions, watchdog
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show google-generativeai
# Out:
# Name: google-generativeai
# Version: 0.4.1
# Summary: Google Generative AI High level API client library and tools.
# Home-page: https://github.com/google/generative-ai-python
# Author: Google LLC
# Author-email: googleapis-packages@google.com
# License: Apache 2.0
# Location: E:\PYTHONCODES\talkImage\Lib\site-packages
# Requires: google-ai-generativelanguage, google-api-core, google-auth, protobuf, pydantic, tqdm, typing-extensions
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv(),override=True)
os.environ.get('GOOGLE_API_KEY')
print(os.environ.get('GOOGLE_API_KEY'))
# Out:
# AIzaSyBIvtPg_WMbo3POODEuJdZONuvxMdZegVo

# %%
genai.configure(api_key=os.environ.get('GOOGLE_API_KEY'))

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in e:\pythoncodes\talkimage\lib\site-packages (10.2.0)

# %%
from PIL import Image

# %%
image_path = input('Enter image path: ')

if not os.path.isfile(image_path):
    raise SystemExit('Invalid path! Existing ...')

img = Image.open(image_path)
img
# Out:
# Enter image path:  E:\PYTHONCODES\talkImage\codes\salad.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=511x360>

# %%
import time
model = genai.GenerativeModel('gemini-pro-vision')
while True:
    prompt = input('Ask something: ')
    if prompt.lower() not in ['exit', 'bye', 'quit']:
        response = model.generate_content([prompt, img])
        print('')
        print(response.text)
        print('-' * 100)
    else:
        print('Quitting ...')
        time.sleep(2)
        print('Bye-bye!')
        break
# Out:
#   Cell In[12], line 14
#     break
#     ^
# SyntaxError: invalid non-printable character U+00A0

# %%
import time
model = genai.GenerativeModel('gemini-pro-vision')
while True:
    prompt = input('Ask something: ')
    if prompt.lower() not in ['exit', 'bye', 'quit']:
        response = model.generate_content([prompt, img])
        print('')
        print(response.text)
        print('-' * 100)
    else:
        print('Quitting ...')
        time.sleep(2)
        print('Bye-bye!')
        break
# Out:
#   Cell In[13], line 14
#     break
#     ^
# SyntaxError: invalid non-printable character U+00A0

# %%
import time
model = genai.GenerativeModel('gemini-pro-vision')
while True:
    prompt = input('Ask something: ')
    if prompt.lower() not in ['exit', 'bye', 'quit']:
        response = model.generate_content([prompt, img])
        print('')
        print(response.text)
        print('-' * 100)
    else:
        print('Quitting ...')
        time.sleep(2)
        print('Bye-bye!')
        break
# Out:
# Ask something:  list the image items
#  The image contains the following items:
#
# * cucumber
# * tomato
# * onion
# * pepper
# * lettuce
# * olives
# * feta cheese
# ----------------------------------------------------------------------------------------------------
# Ask something:  prepare a breakfast using these items and insure the calorie consumption should be within 1300kcal
#  A Greek salad is a great option for a healthy breakfast. It is made with fresh vegetables, such as tomatoes, cucumbers, onions, and olives, and is topped with feta cheese and olive oil. This salad is low in calories and fat, and is high in fiber and protein. It is also a good source of vitamins and minerals, such as vitamin C, potassium, and iron.
#
# To make a Greek salad, you will need the following ingredients:
#
# * 1 head of romaine lettuce, chopped
# * 1 cucumber, chopped
# * 1 tomato, chopped
# * 1/2 cup of red onion, chopped
# * 1/4 cup of kalamata olives, pitted
# * 1/4 cup of feta cheese, crumbled
# * 1/4 cup of olive oil
# * 1 tablespoon of red wine vinegar
# * 1 teaspoon of oregano
# * 1/2 teaspoon of salt
# * 1/4 teaspoon of black pepper
#
# Instructions:
#
# 1. In a large bowl, combine the romaine lettuce, cucumber, tomato, red onion, kalamata olives, and feta cheese.
# 2. In a small bowl, whisk together the olive oil, red wine vinegar, oregano, salt, and black pepper.
# 3. Pour the dressing over the salad and toss to coat.
#
# Serve immediately.
#
# This salad is a great way to start your day off on a healthy note. It is light and refreshing, and will give you the energy you need to get through the morning.
# ----------------------------------------------------------------------------------------------------
# Ask something:  bye
# Quitting ...
# Bye-bye!
